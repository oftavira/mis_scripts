# %%
# Obtención de proxys y user agents automatizada, utiles en el proceso de web scraping

import requests

from bs4    import BeautifulSoup
from urllib import request

uri_prox  = "https://free-proxy-list.net/"
uri_users = "https://developers.whatismybrowser.com/useragents/explore/software_type_specific/web-browser/"

prox  = requests.get(uri_prox).text
users = requests.get(uri_users).text

soup_prox  = BeautifulSoup(prox ,'lxml')
soup_users = BeautifulSoup(users,'lxml')

taged_prox_ls = soup_prox.findChild("tbody")
listed_prox   = [tag for tag in taged_prox_ls.find_all("tr")]

prox_table  = {}
count       = 0

for Result in listed_prox:
    listed_props = Result.find_all("td")
    IP      =  listed_props[0].get_text()
    PORT    =  listed_props[1].get_text()
    COUNTRY =  listed_props[3].get_text()
    P_TYPE  =  listed_props[4].get_text()
    HTTP    =  listed_props[6].get_text()
    
    proxie  =  {
        "IP"  : IP,
        "PORT": PORT,
        "COUNTRY": COUNTRY,
        "P_TYPE": P_TYPE,
        "HTTPS": HTTP,
    }
    prox_table.update({"PROXY"+ str(count) : proxie})
    count += 1

taged_usrs_ls = soup_users.findChild("tbody")
listed_usrs   = [taged_usr for taged_usr in taged_usrs_ls.find_all("tr")]
users = [user.findChild("td").text for user in listed_usrs]

# %%
prox_table
# Out:
# 93.42.134',
#   'PORT': '47803',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY143': {'IP': '91.203.114.74',
#   'PORT': '58074',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY144': {'IP': '200.69.81.198',
#   'PORT': '58593',
#   'COUNTRY': 'Colombia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY145': {'IP': '103.105.77.48',
#   'PORT': '8181',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY146': {'IP': '203.189.89.1',
#   'PORT': '53281',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY147': {'IP': '213.6.38.50',
#   'PORT': '59840',
#   'COUNTRY': 'Palestinian Territory',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY148': {'IP': '94.230.158.37',
#   'PORT': '39509',
#   'COUNTRY': 'Czech Republic',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY149': {'IP': '101.51.106.70',
#   'PORT': '45699',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY150': {'IP': '109.195.23.223',
#   'PORT': '34542',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY151': {'IP': '85.90.215.111',
#   'PORT': '3128',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY152': {'IP': '88.99.10.252',
#   'PORT': '1080',
#   'COUNTRY': 'Germany',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY153': {'IP': '197.210.153.126',
#   'PORT': '51616',
#   'COUNTRY': 'Nigeria',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY154': {'IP': '181.211.245.74',
#   'PORT': '44267',
#   'COUNTRY': 'Ecuador',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY155': {'IP': '46.39.245.204',
#   'PORT': '54108',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY156': {'IP': '118.174.220.14',
#   'PORT': '43473',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY157': {'IP': '94.127.144.179',
#   'PORT': '33905',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY158': {'IP': '114.134.186.59',
#   'PORT': '39777',
#   'COUNTRY': 'Cambodia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY159': {'IP': '103.9.188.229',
#   'PORT': '36984',
#   'COUNTRY': 'Cambodia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY160': {'IP': '37.232.13.54',
#   'PORT': '51296',
#   'COUNTRY': 'Georgia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY161': {'IP': '117.242.147.181',
#   'PORT': '48258',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY162': {'IP': '91.200.124.197',
#   'PORT': '30845',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY163': {'IP': '117.240.59.115',
#   'PORT': '36127',
#   'COUNTRY': 'India',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY164': {'IP': '125.27.251.160',
#   'PORT': '48467',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY165': {'IP': '77.66.203.114',
#   'PORT': '33097',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY166': {'IP': '31.40.136.176',
#   'PORT': '53281',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY167': {'IP': '212.2.204.181',
#   'PORT': '60725',
#   'COUNTRY': 'Turkey',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY168': {'IP': '91.234.127.222',
#   'PORT': '53281',
#   'COUNTRY': 'Poland',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY169': {'IP': '36.37.160.224',
#   'PORT': '23500',
#   'COUNTRY': 'Cambodia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY170': {'IP': '119.82.253.123',
#   'PORT': '48405',
#   'COUNTRY': 'Cambodia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY171': {'IP': '160.119.131.114',
#   'PORT': '34453',
#   'COUNTRY': 'Guinea',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY172': {'IP': '103.208.200.114',
#   'PORT': '23500',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY173': {'IP': '118.174.220.133',
#   'PORT': '50616',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY174': {'IP': '95.140.27.135',
#   'PORT': '36316',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY175': {'IP': '27.50.18.42',
#   'PORT': '23500',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY176': {'IP': '103.82.43.233',
#   'PORT': '51811',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY177': {'IP': '118.99.100.204',
#   'PORT': '8080',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY178': {'IP': '103.224.5.5',
#   'PORT': '54143',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY179': {'IP': '109.121.207.165',
#   'PORT': '48834',
#   'COUNTRY': 'Bulgaria',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY180': {'IP': '103.105.77.38',
#   'PORT': '8181',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY181': {'IP': '103.105.77.21',
#   'PORT': '8080',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY182': {'IP': '79.101.55.161',
#   'PORT': '53281',
#   'COUNTRY': 'Serbia',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY183': {'IP': '187.109.40.193',
#   'PORT': '20183',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY184': {'IP': '183.91.87.45',
#   'PORT': '3128',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY185': {'IP': '154.0.0.4',
#   'PORT': '8080',
#   'COUNTRY': 'South Africa',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY186': {'IP': '190.119.187.194',
#   'PORT': '8080',
#   'COUNTRY': 'Peru',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY187': {'IP': '41.191.245.46',
#   'PORT': '8080',
#   'COUNTRY': 'Ghana',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY188': {'IP': '103.89.235.169',
#   'PORT': '82',
#   'COUNTRY': 'India',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY189': {'IP': '103.89.233.101',
#   'PORT': '82',
#   'COUNTRY': 'India',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY190': {'IP': '79.190.145.141',
#   'PORT': '3128',
#   'COUNTRY': 'Poland',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY191': {'IP': '50.233.228.147',
#   'PORT': '8080',
#   'COUNTRY': 'United States',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY192': {'IP': '92.249.122.108',
#   'PORT': '61778',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY193': {'IP': '5.44.107.147',
#   'PORT': '3128',
#   'COUNTRY': 'Germany',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY194': {'IP': '115.249.2.192',
#   'PORT': '8080',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY195': {'IP': '41.72.203.66',
#   'PORT': '38064',
#   'COUNTRY': 'Kenya',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY196': {'IP': '217.78.1.91',
#   'PORT': '3128',
#   'COUNTRY': 'Ireland',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY197': {'IP': '209.97.164.211',
#   'PORT': '47503',
#   'COUNTRY': 'Singapore',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY198': {'IP': '176.106.255.3',
#   'PORT': '8080',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY199': {'IP': '84.53.247.204',
#   'PORT': '53281',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY200': {'IP': '181.196.205.250',
#   'PORT': '44321',
#   'COUNTRY': 'Ecuador',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY201': {'IP': '207.144.111.230',
#   'PORT': '8080',
#   'COUNTRY': 'United States',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY202': {'IP': '200.206.50.66',
#   'PORT': '42515',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY203': {'IP': '200.116.226.210',
#   'PORT': '43049',
#   'COUNTRY': 'Colombia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY204': {'IP': '176.117.255.182',
#   'PORT': '53100',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY205': {'IP': '182.52.238.119',
#   'PORT': '40456',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY206': {'IP': '144.76.214.156',
#   'PORT': '1080',
#   'COUNTRY': 'Germany',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY207': {'IP': '45.115.173.205',
#   'PORT': '3128',
#   'COUNTRY': 'India',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY208': {'IP': '182.176.228.147',
#   'PORT': '57472',
#   'COUNTRY': 'Pakistan',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY209': {'IP': '144.76.214.154',
#   'PORT': '1080',
#   'COUNTRY': 'Germany',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY210': {'IP': '91.206.210.54',
#   'PORT': '46698',
#   'COUNTRY': 'Poland',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY211': {'IP': '91.150.189.122',
#   'PORT': '55869',
#   'COUNTRY': 'Poland',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY212': {'IP': '109.175.29.22',
#   'PORT': '37100',
#   'COUNTRY': 'Bosnia and Herzegovina',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY213': {'IP': '66.96.193.206',
#   'PORT': '8080',
#   'COUNTRY': 'Singapore',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY214': {'IP': '175.100.103.157',
#   'PORT': '8080',
#   'COUNTRY': 'Cambodia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY215': {'IP': '173.46.67.172',
#   'PORT': '58517',
#   'COUNTRY': 'United States',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY216': {'IP': '36.92.219.58',
#   'PORT': '8080',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY217': {'IP': '117.212.194.117',
#   'PORT': '58734',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY218': {'IP': '89.42.133.58',
#   'PORT': '8080',
#   'COUNTRY': 'Romania',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY219': {'IP': '1.10.186.114',
#   'PORT': '55824',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY220': {'IP': '176.120.212.114',
#   'PORT': '53281',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY221': {'IP': '103.216.82.153',
#   'PORT': '35101',
#   'COUNTRY': 'India',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY222': {'IP': '45.121.29.254',
#   'PORT': '54858',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY223': {'IP': '139.255.96.134',
#   'PORT': '53281',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY224': {'IP': '84.53.238.49',
#   'PORT': '23500',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY225': {'IP': '188.40.183.184',
#   'PORT': '1080',
#   'COUNTRY': 'Germany',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY226': {'IP': '93.64.183.162',
#   'PORT': '56508',
#   'COUNTRY': 'Italy',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY227': {'IP': '103.239.253.218',
#   'PORT': '31913',
#   'COUNTRY': 'Bangladesh',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY228': {'IP': '45.32.122.219',
#   'PORT': '57376',
#   'COUNTRY': 'Singapore',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY229': {'IP': '188.170.41.6',
#   'PORT': '60332',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY230': {'IP': '175.106.17.62',
#   'PORT': '30544',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY231': {'IP': '85.159.48.170',
#   'PORT': '40014',
#   'COUNTRY': 'Hungary',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY232': {'IP': '182.53.206.26',
#   'PORT': '45336',
#   'COUNTRY': 'Thailand',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY233': {'IP': '41.169.11.210',
#   'PORT': '45088',
#   'COUNTRY': 'South Africa',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY234': {'IP': '103.105.212.106',
#   'PORT': '53281',
#   'COUNTRY': 'Philippines',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY235': {'IP': '103.94.171.134',
#   'PORT': '46276',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY236': {'IP': '103.37.81.92',
#   'PORT': '42420',
#   'COUNTRY': 'India',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY237': {'IP': '119.82.253.24',
#   'PORT': '44060',
#   'COUNTRY': 'Cambodia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY238': {'IP': '81.24.95.106',
#   'PORT': '41258',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY239': {'IP': '186.159.2.241',
#   'PORT': '43459',
#   'COUNTRY': 'Colombia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY240': {'IP': '41.190.95.92',
#   'PORT': '47720',
#   'COUNTRY': 'Malawi',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY241': {'IP': '212.42.113.96',
#   'PORT': '3128',
#   'COUNTRY': 'Kyrgyzstan',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY242': {'IP': '82.200.9.234',
#   'PORT': '47284',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY243': {'IP': '103.81.114.182',
#   'PORT': '53281',
#   'COUNTRY': 'Myanmar',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY244': {'IP': '5.164.131.194',
#   'PORT': '53281',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY245': {'IP': '187.111.160.8',
#   'PORT': '42579',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY246': {'IP': '91.226.35.93',
#   'PORT': '53281',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY247': {'IP': '119.81.189.194',
#   'PORT': '8123',
#   'COUNTRY': 'Hong Kong',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY248': {'IP': '41.190.95.20',
#   'PORT': '56167',
#   'COUNTRY': 'Malawi',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY249': {'IP': '117.58.241.164',
#   'PORT': '52636',
#   'COUNTRY': 'Bangladesh',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY250': {'IP': '103.250.152.62',
#   'PORT': '36664',
#   'COUNTRY': 'India',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY251': {'IP': '52.179.231.206',
#   'PORT': '80',
#   'COUNTRY': 'United States',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY252': {'IP': '176.62.185.72',
#   'PORT': '45277',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY253': {'IP': '103.74.70.142',
#   'PORT': '35754',
#   'COUNTRY': 'India',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY254': {'IP': '80.59.199.213',
#   'PORT': '8080',
#   'COUNTRY': 'Spain',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY255': {'IP': '103.106.238.230',
#   'PORT': '50941',
#   'COUNTRY': 'Bangladesh',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY256': {'IP': '176.196.84.138',
#   'PORT': '51336',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY257': {'IP': '106.185.153.130',
#   'PORT': '8118',
#   'COUNTRY': 'Japan',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY258': {'IP': '60.248.199.206',
#   'PORT': '80',
#   'COUNTRY': 'Taiwan',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY259': {'IP': '201.55.160.18',
#   'PORT': '3128',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY260': {'IP': '150.109.32.166',
#   'PORT': '80',
#   'COUNTRY': 'Hong Kong',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY261': {'IP': '188.129.161.55',
#   'PORT': '36631',
#   'COUNTRY': 'Georgia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY262': {'IP': '103.250.156.22',
#   'PORT': '30093',
#   'COUNTRY': 'India',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY263': {'IP': '81.95.131.10',
#   'PORT': '44292',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY264': {'IP': '178.93.35.171',
#   'PORT': '53281',
#   'COUNTRY': 'Ukraine',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY265': {'IP': '62.152.60.42',
#   'PORT': '3128',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY266': {'IP': '140.227.211.122',
#   'PORT': '3128',
#   'COUNTRY': 'Japan',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY267': {'IP': '84.166.150.122',
#   'PORT': '8080',
#   'COUNTRY': 'Germany',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY268': {'IP': '202.142.162.54',
#   'PORT': '3128',
#   'COUNTRY': 'Pakistan',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY269': {'IP': '31.192.131.152',
#   'PORT': '53281',
#   'COUNTRY': 'Russian Federation',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY270': {'IP': '124.158.175.26',
#   'PORT': '8080',
#   'COUNTRY': 'Indonesia',
#   'P_TYPE': 'transparent',
#   'HTTPS': 'no'},
#  'PROXY271': {'IP': '200.68.13.26',
#   'PORT': '56000',
#   'COUNTRY': 'Chile',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY272': {'IP': '186.10.65.3',
#   'PORT': '999',
#   'COUNTRY': 'Chile',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY273': {'IP': '45.71.108.18',
#   'PORT': '46114',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY274': {'IP': '186.189.235.121',
#   'PORT': '80',
#   'COUNTRY': 'Argentina',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY275': {'IP': '200.73.129.85',
#   'PORT': '3128',
#   'COUNTRY': 'Argentina',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY276': {'IP': '200.89.178.213',
#   'PORT': '8080',
#   'COUNTRY': 'Argentina',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY277': {'IP': '186.159.3.193',
#   'PORT': '41741',
#   'COUNTRY': 'Colombia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY278': {'IP': '103.93.233.14',
#   'PORT': '8080',
#   'COUNTRY': 'Australia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY279': {'IP': '138.197.157.44',
#   'PORT': '8080',
#   'COUNTRY': 'Canada',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY280': {'IP': '187.17.19.90',
#   'PORT': '57685',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY281': {'IP': '200.150.86.138',
#   'PORT': '44677',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY282': {'IP': '200.89.159.240',
#   'PORT': '3128',
#   'COUNTRY': 'Argentina',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY283': {'IP': '187.60.34.234',
#   'PORT': '53597',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY284': {'IP': '61.29.96.146',
#   'PORT': '80',
#   'COUNTRY': 'Australia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY285': {'IP': '85.187.17.39',
#   'PORT': '53281',
#   'COUNTRY': 'Bulgaria',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY286': {'IP': '185.44.229.227',
#   'PORT': '34930',
#   'COUNTRY': 'Armenia',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'yes'},
#  'PROXY287': {'IP': '54.233.167.111',
#   'PORT': '3128',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY288': {'IP': '200.255.122.170',
#   'PORT': '8080',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'yes'},
#  'PROXY289': {'IP': '142.93.147.192',
#   'PORT': '8118',
#   'COUNTRY': 'Canada',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY290': {'IP': '138.197.145.103',
#   'PORT': '8080',
#   'COUNTRY': 'Canada',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY291': {'IP': '144.217.103.67',
#   'PORT': '8080',
#   'COUNTRY': 'Canada',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY292': {'IP': '177.94.206.67',
#   'PORT': '60666',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY293': {'IP': '187.111.176.62',
#   'PORT': '8080',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY294': {'IP': '203.202.245.58',
#   'PORT': '80',
#   'COUNTRY': 'Bangladesh',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY295': {'IP': '200.236.221.242',
#   'PORT': '36729',
#   'COUNTRY': 'Brazil',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY296': {'IP': '200.89.178.216',
#   'PORT': '8080',
#   'COUNTRY': 'Argentina',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'},
#  'PROXY297': {'IP': '91.187.116.232',
#   'PORT': '44981',
#   'COUNTRY': 'Albania',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY298': {'IP': '103.85.217.1',
#   'PORT': '41330',
#   'COUNTRY': 'Bangladesh',
#   'P_TYPE': 'elite proxy',
#   'HTTPS': 'no'},
#  'PROXY299': {'IP': '203.19.88.51',
#   'PORT': '80',
#   'COUNTRY': 'Australia',
#   'P_TYPE': 'anonymous',
#   'HTTPS': 'no'}}

# %%
users
# Out:
# ['Mozilla/5.0 CK={} (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36',
#  'Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322)',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.1 Mobile/15E148 Safari/604.1',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36 Edge/17.17134',
#  'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; KTXN)',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36 Edge/18.17763',
#  'Mozilla/5.0 (Windows NT 5.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:54.0) Gecko/20100101 Firefox/54.0',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.1',
#  'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
#  'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0)',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 12_1_4 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/16D57',
#  'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko)',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:18.0) Gecko/20100101 Firefox/18.0',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)',
#  'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/605.1.15 (KHTML, like Gecko)',
#  'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1; 125LA; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022)',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; .NET CLR 1.1.4322)',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 13_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.4 Mobile/15E148 Safari/604.1',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 12_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148',
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.0)',
#  'Mozilla/5.0 (Linux; U; Android 2.2) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1',
#  'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.71 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
#  'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.83 Safari/537.1',
#  'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko)',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393',
#  'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
#  'Mozilla/5.0 (iPhone; CPU iPhone OS 13_1_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.1 Mobile/15E148 Safari/604.1',
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
#  'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/605.1.15 (KHTML, like Gecko)',
#  'Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Mobile/13G36']
